# %% [markdown]
# # 1. _Ocorrências aeronáuticas na aviação civil brasileira_
# ##### Introdução a Banco de Dados - 2019/2 - Turma TM

# %%
# Basic imports
import os
import sqlite3
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2. Membros

# %% [markdown]
# * Gabriel Luz - 2017015126
# * Elves M. Rodrigues - PUT NUMBER
# *  Luiz Henrique Melo - 2017014464
# * Otavio Augusto Silva - 2016006808

# %% [markdown]
# ### 3. Descrição dos dados

# %% [markdown]
# #### Preâmbulo
#
# Neste tópico será feita uma amostragem dos dados por meio da biblioteca Pandas do Python e observações do tipo dos dados que serão utilizados, tais como dados faltantes, além da promoção da junção das tabelas em uma única, a fim de melhor organização dos dados para futura instanciação.
#
# Os dados têm como fonte o Portal Brasileiro de Dados Abertos, podendo ser acessado por [aqui](http://dados.gov.br/dataset/ocorrencias-aeronauticas-da-aviacao-civil-brasileira).
#
# A imagem abaixa foi extraída da URL original da fonte dos dados e provém uma melhor descrição dos dados, tal como a sua fonte e seu schema.

# %% [markdown]
# ![title](images/data_model.png)

# %% [markdown]
# #### Amostragem dos dados
#
# ##### Aeronaves envolvidas no acidente

# %%
anv = pd.read_csv('../data/anv.csv', sep='~')
anv
# Out:
#       codigo_ocorrencia aeronave_matricula aeronave_operador_categoria  \
# 0       201106142171203              PPGXE                   AEROCLUBE
# 1       201205209591320              PTRBN        OPERADOR DE AERONAVE
# 2       201012015549851              PTKUK        OPERADOR DE AERONAVE
# 3       201708190325167              PTKUK         OPERADOR PARTICULAR
# 4       201803182255192              PPGSZ                   AEROCLUBE
# ...                 ...                ...                         ...
# 5518    201903271943019              PRFKU         OPERADOR PARTICULAR
# 5519    201904241650016              PPSEK         OPERADOR PARTICULAR
# 5520    201904261718061             N100QR         OPERADOR PARTICULAR
# 5521    201905061442135              PRCGF        OPERADOR DE AERONAVE
# 5522    201905171937061             LVGVB         OPERADOR DE AERONAVE
#
#      aeronave_tipo_veiculo          aeronave_fabricante aeronave_modelo  \
# 0                    AVIÃO  NEIVA INDUSTRIA AERONAUTICA            56-C
# 1                    AVIÃO                      EMBRAER        EMB-810C
# 2                    AVIÃO               TWIN COMMANDER           500-B
# 3                    AVIÃO               TWIN COMMANDER           500-B
# 4                    AVIÃO  NEIVA INDUSTRIA AERONAUTICA            56-C
# ...                    ...                          ...             ...
# 5518                 AVIÃO                  AIR TRACTOR          AT-502
# 5519           HELICÓPTERO          ROBINSON HELICOPTER          R44 II
# 5520                 AVIÃO                     CANADAIR     CL-600-1A11
# 5521           HELICÓPTERO            SIKORSKY AIRCRAFT           S-92A
# 5522                 AVIÃO               BOEING COMPANY         737-887
#
#      aeronave_tipo_icao aeronave_motor_tipo aeronave_motor_quantidade  \
# 0                  PAUL              PISTÃO                 MONOMOTOR
# 1                  PA34              PISTÃO                   BIMOTOR
# 2                  AC50              PISTÃO                   BIMOTOR
# 3                  AC50              PISTÃO                   BIMOTOR
# 4                  PAUL              PISTÃO                 MONOMOTOR
# ...                 ...                 ...                       ...
# 5518               AT5T          TURBOÉLICE                 MONOMOTOR
# 5519                R44              PISTÃO                 MONOMOTOR
# 5520               CL60                JATO                   BIMOTOR
# 5521                S92           TURBOEIXO                       ***
# 5522               B737                JATO                   BIMOTOR
#
#       aeronave_pmd  ... aeronave_registro_categoria  \
# 0              660  ...                         PRI
# 1             2073  ...                         TPX
# 2             3062  ...                         TPX
# 3             3062  ...                         SAE
# 4              660  ...                         PRI
# ...            ...  ...                         ...
# 5518          2948  ...                      SAE-AG
# 5519          1134  ...                         TPP
# 5520         20457  ...                         TPP
# 5521         12020  ...                         TPX
# 5522         79015  ...                         TPR
#
#       aeronave_registro_segmento  aeronave_voo_origem aeronave_voo_destino  \
# 0                      INSTRUÇÃO                 SDPW                 SDPW
# 1                     TÁXI AÉREO                 ****                 ****
# 2                     TÁXI AÉREO                 ****                 ****
# 3                  ESPECIALIZADA                 SBCP                 SBCP
# 4                      INSTRUÇÃO                 SBBP                 SBBP
# ...                          ...                  ...                  ...
# 5518                    AGRÍCOLA                 ****                 ****
# 5519                  PARTICULAR                 ###!                 SBCN
# 5520                  PARTICULAR                 SADF                 SBCB
# 5521                  TÁXI AÉREO                 SBCP                 SBCP
# 5522                     REGULAR                 SABE                 SBGR
#
#      aeronave_fase_operacao aeronave_fase_operacao_icao  \
# 0             INDETERMINADA                     UNKNOWN
# 1         APROXIMAÇÃO FINAL                    APPROACH
# 2        CORRIDA APÓS POUSO                     LANDING
# 3                  CRUZEIRO                    EN ROUTE
# 4        ARREMETIDA NO SOLO                    APPROACH
# ...                     ...                         ...
# 5518              DECOLAGEM                     TAKEOFF
# 5519               CRUZEIRO                    EN ROUTE
# 5520      APROXIMAÇÃO FINAL                    APPROACH
# 5521                 SUBIDA                    EN ROUTE
# 5522                   TÁXI                        TAXI
#
#       aeronave_tipo_operacao aeronave_nivel_dano total_fatalidades  \
# 0           VOO DE INSTRUÇÃO         SUBSTANCIAL                 0
# 1                 TÁXI AÉREO              NENHUM                 0
# 2                 TÁXI AÉREO                LEVE                 0
# 3     OPERAÇÃO ESPECIALIZADA                LEVE                 0
# 4           VOO DE INSTRUÇÃO                LEVE                 0
# ...                      ...                 ...               ...
# 5518       OPERAÇÃO AGRÍCOLA         SUBSTANCIAL                 0
# 5519             VOO PRIVADO              NENHUM                 0
# 5520             VOO PRIVADO              NENHUM                 0
# 5521              TÁXI AÉREO              NENHUM                 0
# 5522             VOO REGULAR              NENHUM                 0
#
#      aeronave_dia_extracao
# 0               2019-05-31
# 1               2019-05-31
# 2               2019-05-31
# 3               2019-05-31
# 4               2019-05-31
# ...                    ...
# 5518            2019-05-31
# 5519            2019-05-31
# 5520            2019-05-31
# 5521            2019-05-31
# 5522            2019-05-31
#
# [5523 rows x 25 columns]

# %% [markdown]
# ##### Fatores contribuintes para o acidente

# %%
ftc = pd.read_csv('../data/ftc.csv', sep='~')
ftc
# Out:
#       codigo_ocorrencia                         fator_nome  \
# 0       200901015424167            JULGAMENTO DE PILOTAGEM
# 1       200901015424167             MANUTENÇÃO DE AERONAVE
# 2       200901015424167               SUPERVISÃO GERENCIAL
# 3       200901055963381                            ATITUDE
# 4       200901055963381                 PROCESSO DECISÓRIO
# ...                 ...                                ...
# 4625    201901141204402                      DESORIENTAÇÃO
# 4626    201901141204402              APLICAÇÃO DE COMANDOS
# 4627    201901141204402  CONDIÇÕES METEOROLÓGICAS ADVERSAS
# 4628    201901141204402            JULGAMENTO DE PILOTAGEM
# 4629    201901141204402        POUCA EXPERIÊNCIA DO PILOTO
#
#                  fator_aspecto     fator_condicionante         fator_area  \
# 0     DESEMPENHO DO SER HUMANO    OPERAÇÃO DA AERONAVE  FATOR OPERACIONAL
# 1     DESEMPENHO DO SER HUMANO  MANUTENÇÃO DA AERONAVE  FATOR OPERACIONAL
# 2     DESEMPENHO DO SER HUMANO    OPERAÇÃO DA AERONAVE  FATOR OPERACIONAL
# 3          ASPECTO PSICOLÓGICO              INDIVIDUAL       FATOR HUMANO
# 4          ASPECTO PSICOLÓGICO              INDIVIDUAL       FATOR HUMANO
# ...                        ...                     ...                ...
# 4625            ASPECTO MÉDICO                     ***       FATOR HUMANO
# 4626  DESEMPENHO DO SER HUMANO    OPERAÇÃO DA AERONAVE  FATOR OPERACIONAL
# 4627                       ***                     ***                ***
# 4628  DESEMPENHO DO SER HUMANO    OPERAÇÃO DA AERONAVE  FATOR OPERACIONAL
# 4629  DESEMPENHO DO SER HUMANO    OPERAÇÃO DA AERONAVE  FATOR OPERACIONAL
#
#                                     fator_detalhe_fator fator_dia_extracao
# 0     A PROVÁVEL INTENÇÃO EM PRESERVAR A AERONAVE, C...         2019-05-31
# 1     O RELATÓRIO TÉCNICO DO IAE REVELOU FALHAS ORIU...         2019-05-31
# 2     O OPERADOR NÃO PROGRAMOU A REALIZAÇÃO DE INSPE...         2019-05-31
# 3     O PILOTO ERA POUCO EXPERIENTE E REALIZOU O POU...         2019-05-31
# 4     A POUCA EXPERIÊNCIA DO PILOTO, ALIADA AO EXCES...         2019-05-31
# ...                                                 ...                ...
# 4625                                                NaN         2019-05-31
# 4626                                                NaN         2019-05-31
# 4627                                                NaN         2019-05-31
# 4628                                                NaN         2019-05-31
# 4629                                                NaN         2019-05-31
#
# [4630 rows x 7 columns]

# %% [markdown]
# ##### Ocorrências dos acidentes

# %%
oco = pd.read_csv('../data/oco.csv', sep='~')
oco
# Out:
#       codigo_ocorrencia ocorrencia_classificacao  \
# 0       201305055424986                 ACIDENTE
# 1       201311259977425          INCIDENTE GRAVE
# 2       201605160250139          INCIDENTE GRAVE
# 3       201805021421302                INCIDENTE
# 4       201103187273112                INCIDENTE
# ...                 ...                      ...
# 5455    201107163514591                INCIDENTE
# 5456    201101107541931                INCIDENTE
# 5457    201502247981603          INCIDENTE GRAVE
# 5458    200910311058203                INCIDENTE
# 5459    201309012098180                 ACIDENTE
#
#                                         ocorrencia_tipo  \
# 0                                 FALHA DO MOTOR EM VOO
# 1                                        POUSO SEM TREM
# 2     COLISÃO COM OBSTÁCULO DURANTE A DECOLAGEM E POUSO
# 3                                             AERÓDROMO
# 4                                                OUTROS
# ...                                                 ...
# 5455                                      TRÁFEGO AÉREO
# 5456          CAUSADO POR FENÔMENO METEOROLÓGICO EM VOO
# 5457                   COM PARA-BRISAS / JANELA / PORTA
# 5458  FALHA OU MAU FUNCIONAMENTO DE SISTEMA / COMPON...
# 5459          CAUSADO POR FENÔMENO METEOROLÓGICO EM VOO
#
#                               ocorrencia_tipo_categoria ocorrencia_tipo_icao  \
# 0                   FALHA OU MAU FUNCIONAMENTO DO MOTOR               SCF-PP
# 1                           CONTATO ANORMAL COM A PISTA                  ARC
# 2     COLISÃO COM OBSTÁCULO DURANTE A DECOLAGEM E POUSO                 CTOL
# 3                                             AERÓDROMO                 ADRM
# 4                                                OUTROS                 OTHR
# ...                                                 ...                  ...
# 5455                PERDA DE SEPARAÇÃO / COLISÃO EM VOO                  MAC
# 5456                                             OUTROS                 OTHR
# 5457  FALHA OU MAU FUNCIONAMENTO DE SISTEMA / COMPON...               SCF-NP
# 5458  FALHA OU MAU FUNCIONAMENTO DE SISTEMA / COMPON...               SCF-NP
# 5459                                             OUTROS                 OTHR
#
#       ocorrencia_latitude  ocorrencia_longitude     ocorrencia_cidade  \
# 0                 -9.9085              -63.0333             ARIQUEMES
# 1                -11.4956              -61.4508                CACOAL
# 2                -11.2644              -61.2589                CACOAL
# 3                -11.4956              -61.4508                CACOAL
# 4                -13.1950              -60.8184            CEREJEIRAS
# ...                   ...                   ...                   ...
# 5455               0.0000                0.0000      NÃO IDENTIFICADA
# 5456               0.0000                0.0000      NÃO IDENTIFICADA
# 5457               0.0000                0.0000      NÃO IDENTIFICADA
# 5458               0.0000                0.0000      NÃO IDENTIFICADA
# 5459               6.7119              -32.9919  ÁGUAS INTERNACIONAIS
#
#      ocorrencia_uf ocorrencia_pais  ... ocorrencia_horario  \
# 0               RO          BRASIL  ...           11:00:00
# 1               RO          BRASIL  ...           12:32:00
# 2               RO          BRASIL  ...           19:19:00
# 3               RO          BRASIL  ...           22:40:00
# 4               RO          BRASIL  ...           13:30:00
# ...            ...             ...  ...                ...
# 5455            AM          BRASIL  ...           08:57:00
# 5456            PE          BRASIL  ...           03:00:00
# 5457            RJ          BRASIL  ...           17:51:00
# 5458            SP          BRASIL  ...           12:10:00
# 5459           ***          BRASIL  ...           02:54:00
#
#      investigacao_aeronave_liberada investigacao_status  \
# 0                               NaN          FINALIZADA
# 1                               NaN          FINALIZADA
# 2                               SIM          FINALIZADA
# 3                               SIM          FINALIZADA
# 4                               NaN          FINALIZADA
# ...                             ...                 ...
# 5455                            NaN          FINALIZADA
# 5456                            NaN          FINALIZADA
# 5457                            NaN               ATIVA
# 5458                            NaN          FINALIZADA
# 5459                            NaN          FINALIZADA
#
#      divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                            ***                            NÃO
# 1             IG-209/CENIPA/2013                            SIM
# 2             IG-084/CENIPA/2016                            SIM
# 3                            ***                            NÃO
# 4                            ***                            NÃO
# ...                          ...                            ...
# 5455                         ***                            NÃO
# 5456                         ***                            NÃO
# 5457          IG-027/CENIPA/2015                            NÃO
# 5458                         ***                            NÃO
# 5459           A-158/CENIPA/2013                            SIM
#
#      divulgacao_dia_publicacao total_recomendacoes total_aeronaves_envolvidas  \
# 0                          NaN                   0                          1
# 1                   2014-04-07                   0                          1
# 2                   2019-03-11                   7                          1
# 3                          NaN                   0                          1
# 4                          NaN                   0                          1
# ...                        ...                 ...                        ...
# 5455                       NaN                   0                          1
# 5456                       NaN                   0                          1
# 5457                       NaN                   0                          1
# 5458                       NaN                   0                          1
# 5459                2018-05-10                   2                          1
#
#       ocorrencia_saida_pista  ocorrencia_dia_extracao
# 0                        NÃO               2019-05-31
# 1                        NÃO               2019-05-31
# 2                        NÃO               2019-05-31
# 3                        NÃO               2019-05-31
# 4                        NÃO               2019-05-31
# ...                      ...                      ...
# 5455                     NÃO               2019-05-31
# 5456                     NÃO               2019-05-31
# 5457                     NÃO               2019-05-31
# 5458                     NÃO               2019-05-31
# 5459                     NÃO               2019-05-31
#
# [5460 rows x 22 columns]

# %% [markdown]
# ##### Recomendações de segurança

# %%
rec = pd.read_csv('../data/rec.csv', sep='~')
rec
# Out:
#       codigo_ocorrencia        recomendacao_numero  \
# 0       200901015424167                   123/2012
# 1       200901015424167                   122/2012
# 2       200901015424167                   121/2012
# 3       200901015424167                   120/2012
# 4       200901015424167                   119/2012
# ...                 ...                        ...
# 2054    201812301440298       A-192/CENIPA/2018-01
# 2055    201901141204402     A-009/CENIPA/2019 - 01
# 2056    201902020208112  IG-025/CENIPA/2019 - 01
# 2057    201903061708253   IG-036/CENIPA/2019 - 01
# 2058    201903061708253    IG-036/CENIPA/2019 - 02
#
#      recomendacao_dia_assinatura recomendacao_dia_encaminhamento  \
# 0                     2012-03-22                      2012-04-20
# 1                     2012-03-22                      2012-04-20
# 2                     2012-03-22                      2012-04-20
# 3                     2012-03-22                      2012-04-20
# 4                     2012-03-22                      2012-04-20
# ...                          ...                             ...
# 2054                  2019-05-16                      2019-05-22
# 2055                  2019-05-16                      2019-05-22
# 2056                  2019-05-16                      2019-05-27
# 2057                  2019-05-16                             NaN
# 2058                  2019-05-16                             NaN
#
#      recomendacao_feedback                              recomendacao_conteudo  \
# 0                      NaN  Dar ampla divulgação aos operadores de aeronav...
# 1               2012-11-26  Realizar fiscalização mais rigorosa na vistori...
# 2                      NaN  Aplicar processos que melhorem a qualidade da ...
# 3                      NaN  Promover a atualização de todos os registros d...
# 4                      NaN  Enfatizar o estrito cumprimento dos procedimen...
# ...                    ...                                                ...
# 2054                   NaN  Divulgar os ensinamentos colhidos na presente ...
# 2055                   NaN  Divulgar os ensinamentos colhidos com a presen...
# 2056                   NaN  Atuar junto ao Operador do Aeródromo de SWCA, ...
# 2057                   NaN  Atuar em conjunto com a OCEANAIR LINHAS AEREAS...
# 2058                   NaN  Atuar em conjunto com a OCEANAIR LINHAS AEREAS...
#
#       recomendacao_status recomendacao_destinatario_sigla  \
# 0     AGUARDANDO RESPOSTA                           ABAAC
# 1                CUMPRIDA                            ANAC
# 2     AGUARDANDO RESPOSTA                        AEROCAMP
# 3     AGUARDANDO RESPOSTA                         EXTREME
# 4     AGUARDANDO RESPOSTA                         EXTREME
# ...                   ...                             ...
# 2054  AGUARDANDO RESPOSTA                            ANAC
# 2055  AGUARDANDO RESPOSTA                            ANAC
# 2056  AGUARDANDO RESPOSTA                            ANAC
# 2057  AGUARDANDO RESPOSTA                            ANAC
# 2058  AGUARDANDO RESPOSTA                            ANAC
#
#                          recomendacao_destinatario_nome  \
# 0     ASSOCIAÇÃO BRASILEIRA DE AERONAVES ANTIGAS E C...
# 1                     AGÊNCIA NACIONAL DE AVIAÇÃO CIVIL
# 2             AEROCAMP COMÉRCIO E SERVIÇOS AERONÁUTICOS
# 3                          EXTREME DEMONSTRAÇÕES AÉREAS
# 4                          EXTREME DEMONSTRAÇÕES AÉREAS
# ...                                                 ...
# 2054                  AGÊNCIA NACIONAL DE AVIAÇÃO CIVIL
# 2055                  AGÊNCIA NACIONAL DE AVIAÇÃO CIVIL
# 2056                  AGÊNCIA NACIONAL DE AVIAÇÃO CIVIL
# 2057                  AGÊNCIA NACIONAL DE AVIAÇÃO CIVIL
# 2058                  AGÊNCIA NACIONAL DE AVIAÇÃO CIVIL
#
#      dia_extracao_recomendacao
# 0                   2019-05-31
# 1                   2019-05-31
# 2                   2019-05-31
# 3                   2019-05-31
# 4                   2019-05-31
# ...                        ...
# 2054                2019-05-31
# 2055                2019-05-31
# 2056                2019-05-31
# 2057                2019-05-31
# 2058                2019-05-31
#
# [2059 rows x 10 columns]

# %% [markdown]
# ##### Não sei para que serve este CSV - Risco

# %%
risco_col = ['tipo_transporte', 'matricula', 'aerodromo', 'data', 'hora', 'fase_voo', 'efeito_voo']
risco = pd.read_csv('../data/risco.csv', sep=';', names=risco_col)
risco = risco.drop(risco.index[0]).reset_index()
risco
# Out:
#      index tipo_transporte matricula aerodromo        data   hora  \
# 0        1     AVISTAMENTO   FAB1925      SBYS  03/10/2019  08:10
# 1        2     AVISTAMENTO     PRUDS      SBUR  03/10/2019  17:00
# 2        3     AVISTAMENTO       NaN      SBSP  03/10/2019  09:35
# 3        4     AVISTAMENTO       NaN      SBUL  03/10/2019  15:30
# 4        5     AVISTAMENTO       NaN      SBBH  02/10/2019  13:33
# ..     ...             ...       ...       ...         ...    ...
# 947    948   QUASE COLISÃO      1944      SBYS  01/07/2019  16:00
# 948    949     AVISTAMENTO   FAB2318      SBNT  01/07/2019  12:45
# 949    950         COLISÃO     PRGEC      SWPI  01/07/2019  03:40
# 950    951   QUASE COLISÃO     PRSED      9PCI  01/07/2019  16:20
# 951    952     AVISTAMENTO       NaN      SBES  01/07/2019  08:00
#
#                           fase_voo     efeito_voo
# 0                      Aproximação         Nenhum
# 1                      Aproximação         Nenhum
# 2                 Revisão de pista         Nenhum
# 3    Inspeção de trânsito/intervoo         Nenhum
# 4                      Aproximação  Não reportada
# ..                             ...            ...
# 947                      Decolagem         Nenhum
# 948                    Aproximação         Nenhum
# 949                          Pouso         Nenhum
# 950                          Pouso         Nenhum
# 951                      Decolagem         Nenhum
#
# [952 rows x 8 columns]

# %% [markdown]
# #### Criação do DataBase e instanciação das tabelas
#
# Nesta parte serão feitas as criações das tabelas e instanciação dos dados contidos no DataFrame's criados acima.

# %%
# Criacao do DataBase
if os.path.isfile('aeronautical_occurrences_database.db'):
    # Linka o DataBase ja existente
    conn = sqlite3.connect('aeronautical_occurrences_database.db')
else:
    # Linka o DataBase
    conn = sqlite3.connect('aeronautical_occurrences_database.db')
    
    # Cria as tabelas e instancia as entidades em cada uma delas
    anv.to_sql('AeronavesEnvolvidas', conn, if_exists='replace', index=False)
    ftc.to_sql('FatoresContribuintes', conn, if_exists='replace', index=False)
    oco.to_sql('Ocorrencias', conn, if_exists='replace', index=False)
    rec.to_sql('RecomendacoesSeguranca', conn, if_exists='replace', index=False)

# %% [markdown]
# Checagem do DataBase criado.

# %%
# Aeronaves envolvidas no acidente
pd.read_sql('select * from AeronavesEnvolvidas limit 5', conn)
# Out:
#    codigo_ocorrencia aeronave_matricula aeronave_operador_categoria  \
# 0    201106142171203              PPGXE                   AEROCLUBE
# 1    201205209591320              PTRBN        OPERADOR DE AERONAVE
# 2    201012015549851              PTKUK        OPERADOR DE AERONAVE
# 3    201708190325167              PTKUK         OPERADOR PARTICULAR
# 4    201803182255192              PPGSZ                   AEROCLUBE
#
#   aeronave_tipo_veiculo          aeronave_fabricante aeronave_modelo  \
# 0                 AVIÃO  NEIVA INDUSTRIA AERONAUTICA            56-C
# 1                 AVIÃO                      EMBRAER        EMB-810C
# 2                 AVIÃO               TWIN COMMANDER           500-B
# 3                 AVIÃO               TWIN COMMANDER           500-B
# 4                 AVIÃO  NEIVA INDUSTRIA AERONAUTICA            56-C
#
#   aeronave_tipo_icao aeronave_motor_tipo aeronave_motor_quantidade  \
# 0               PAUL              PISTÃO                 MONOMOTOR
# 1               PA34              PISTÃO                   BIMOTOR
# 2               AC50              PISTÃO                   BIMOTOR
# 3               AC50              PISTÃO                   BIMOTOR
# 4               PAUL              PISTÃO                 MONOMOTOR
#
#    aeronave_pmd  ... aeronave_registro_categoria  aeronave_registro_segmento  \
# 0           660  ...                         PRI                   INSTRUÇÃO
# 1          2073  ...                         TPX                  TÁXI AÉREO
# 2          3062  ...                         TPX                  TÁXI AÉREO
# 3          3062  ...                         SAE               ESPECIALIZADA
# 4           660  ...                         PRI                   INSTRUÇÃO
#
#    aeronave_voo_origem aeronave_voo_destino aeronave_fase_operacao  \
# 0                 SDPW                 SDPW          INDETERMINADA
# 1                 ****                 ****      APROXIMAÇÃO FINAL
# 2                 ****                 ****     CORRIDA APÓS POUSO
# 3                 SBCP                 SBCP               CRUZEIRO
# 4                 SBBP                 SBBP     ARREMETIDA NO SOLO
#
#   aeronave_fase_operacao_icao  aeronave_tipo_operacao aeronave_nivel_dano  \
# 0                     UNKNOWN        VOO DE INSTRUÇÃO         SUBSTANCIAL
# 1                    APPROACH              TÁXI AÉREO              NENHUM
# 2                     LANDING              TÁXI AÉREO                LEVE
# 3                    EN ROUTE  OPERAÇÃO ESPECIALIZADA                LEVE
# 4                    APPROACH        VOO DE INSTRUÇÃO                LEVE
#
#   total_fatalidades aeronave_dia_extracao
# 0                 0            2019-05-31
# 1                 0            2019-05-31
# 2                 0            2019-05-31
# 3                 0            2019-05-31
# 4                 0            2019-05-31
#
# [5 rows x 25 columns]

# %%
# Fatores contribuintes
pd.read_sql('select * from FatoresContribuintes limit 5', conn)
# Out:
#    codigo_ocorrencia               fator_nome             fator_aspecto  \
# 0    200901015424167  JULGAMENTO DE PILOTAGEM  DESEMPENHO DO SER HUMANO
# 1    200901015424167   MANUTENÇÃO DE AERONAVE  DESEMPENHO DO SER HUMANO
# 2    200901015424167     SUPERVISÃO GERENCIAL  DESEMPENHO DO SER HUMANO
# 3    200901055963381                  ATITUDE       ASPECTO PSICOLÓGICO
# 4    200901055963381       PROCESSO DECISÓRIO       ASPECTO PSICOLÓGICO
#
#       fator_condicionante         fator_area  \
# 0    OPERAÇÃO DA AERONAVE  FATOR OPERACIONAL
# 1  MANUTENÇÃO DA AERONAVE  FATOR OPERACIONAL
# 2    OPERAÇÃO DA AERONAVE  FATOR OPERACIONAL
# 3              INDIVIDUAL       FATOR HUMANO
# 4              INDIVIDUAL       FATOR HUMANO
#
#                                  fator_detalhe_fator fator_dia_extracao
# 0  A PROVÁVEL INTENÇÃO EM PRESERVAR A AERONAVE, C...         2019-05-31
# 1  O RELATÓRIO TÉCNICO DO IAE REVELOU FALHAS ORIU...         2019-05-31
# 2  O OPERADOR NÃO PROGRAMOU A REALIZAÇÃO DE INSPE...         2019-05-31
# 3  O PILOTO ERA POUCO EXPERIENTE E REALIZOU O POU...         2019-05-31
# 4  A POUCA EXPERIÊNCIA DO PILOTO, ALIADA AO EXCES...         2019-05-31

# %%
# Ocorrencias de acidentes
pd.read_sql('select * from Ocorrencias limit 5', conn)
# Out:
#    codigo_ocorrencia ocorrencia_classificacao  \
# 0    201305055424986                 ACIDENTE
# 1    201311259977425          INCIDENTE GRAVE
# 2    201605160250139          INCIDENTE GRAVE
# 3    201805021421302                INCIDENTE
# 4    201103187273112                INCIDENTE
#
#                                      ocorrencia_tipo  \
# 0                              FALHA DO MOTOR EM VOO
# 1                                     POUSO SEM TREM
# 2  COLISÃO COM OBSTÁCULO DURANTE A DECOLAGEM E POUSO
# 3                                          AERÓDROMO
# 4                                             OUTROS
#
#                            ocorrencia_tipo_categoria ocorrencia_tipo_icao  \
# 0                FALHA OU MAU FUNCIONAMENTO DO MOTOR               SCF-PP
# 1                        CONTATO ANORMAL COM A PISTA                  ARC
# 2  COLISÃO COM OBSTÁCULO DURANTE A DECOLAGEM E POUSO                 CTOL
# 3                                          AERÓDROMO                 ADRM
# 4                                             OUTROS                 OTHR
#
#    ocorrencia_latitude  ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 0              -9.9085              -63.0333         ARIQUEMES            RO
# 1             -11.4956              -61.4508            CACOAL            RO
# 2             -11.2644              -61.2589            CACOAL            RO
# 3             -11.4956              -61.4508            CACOAL            RO
# 4             -13.1950              -60.8184        CEREJEIRAS            RO
#
#   ocorrencia_pais  ... ocorrencia_horario investigacao_aeronave_liberada  \
# 0          BRASIL  ...           11:00:00                           None
# 1          BRASIL  ...           12:32:00                           None
# 2          BRASIL  ...           19:19:00                            SIM
# 3          BRASIL  ...           22:40:00                            SIM
# 4          BRASIL  ...           13:30:00                           None
#
#   investigacao_status divulgacao_relatorio_numero  \
# 0          FINALIZADA                         ***
# 1          FINALIZADA          IG-209/CENIPA/2013
# 2          FINALIZADA          IG-084/CENIPA/2016
# 3          FINALIZADA                         ***
# 4          FINALIZADA                         ***
#
#   divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 0                            NÃO                      None
# 1                            SIM                2014-04-07
# 2                            SIM                2019-03-11
# 3                            NÃO                      None
# 4                            NÃO                      None
#
#   total_recomendacoes total_aeronaves_envolvidas  ocorrencia_saida_pista  \
# 0                   0                          1                     NÃO
# 1                   0                          1                     NÃO
# 2                   7                          1                     NÃO
# 3                   0                          1                     NÃO
# 4                   0                          1                     NÃO
#
#    ocorrencia_dia_extracao
# 0               2019-05-31
# 1               2019-05-31
# 2               2019-05-31
# 3               2019-05-31
# 4               2019-05-31
#
# [5 rows x 22 columns]

# %%
# Recomendacoes de seguranca
pd.read_sql('select * from RecomendacoesSeguranca limit 5', conn)
# Out:
#    codigo_ocorrencia recomendacao_numero recomendacao_dia_assinatura  \
# 0    200901015424167            123/2012                  2012-03-22
# 1    200901015424167            122/2012                  2012-03-22
# 2    200901015424167            121/2012                  2012-03-22
# 3    200901015424167            120/2012                  2012-03-22
# 4    200901015424167            119/2012                  2012-03-22
#
#   recomendacao_dia_encaminhamento recomendacao_feedback  \
# 0                      2012-04-20                  None
# 1                      2012-04-20            2012-11-26
# 2                      2012-04-20                  None
# 3                      2012-04-20                  None
# 4                      2012-04-20                  None
#
#                                recomendacao_conteudo  recomendacao_status  \
# 0  Dar ampla divulgação aos operadores de aeronav...  AGUARDANDO RESPOSTA
# 1  Realizar fiscalização mais rigorosa na vistori...             CUMPRIDA
# 2  Aplicar processos que melhorem a qualidade da ...  AGUARDANDO RESPOSTA
# 3  Promover a atualização de todos os registros d...  AGUARDANDO RESPOSTA
# 4  Enfatizar o estrito cumprimento dos procedimen...  AGUARDANDO RESPOSTA
#
#   recomendacao_destinatario_sigla  \
# 0                           ABAAC
# 1                            ANAC
# 2                        AEROCAMP
# 3                         EXTREME
# 4                         EXTREME
#
#                       recomendacao_destinatario_nome dia_extracao_recomendacao
# 0  ASSOCIAÇÃO BRASILEIRA DE AERONAVES ANTIGAS E C...                2019-05-31
# 1                  AGÊNCIA NACIONAL DE AVIAÇÃO CIVIL                2019-05-31
# 2          AEROCAMP COMÉRCIO E SERVIÇOS AERONÁUTICOS                2019-05-31
# 3                       EXTREME DEMONSTRAÇÕES AÉREAS                2019-05-31
# 4                       EXTREME DEMONSTRAÇÕES AÉREAS                2019-05-31

# %% [markdown]
# ### 4. Diagrama ER

# %% [markdown]
# ### 5. Diagrama relacional

# %% [markdown]
# ### 6. Consultas

# %% [markdown]
# ### 6.1 Duas consultas envolvendo seleção e projeção

# %% [markdown]
# ### 6.1.1 Consulta 1 (duas versões)

# %% [markdown]
# ### 6.1.2 Consulta 2 (duas versões)

# %% [markdown]
# ### 6.2 Três consultas envolvendo junção de duas relações

# %% [markdown]
# ### 6.2.1 Consulta 3 (duas versões)

# %% [markdown]
# ### 6.2.2 Consulta 4 (duas versões)

# %% [markdown]
# ### 6.2.3 Consulta 5 (duas versões)

# %% [markdown]
# ### 6.3 Três consultas envolvendo junção de três ou mais relações

# %% [markdown]
# ### 6.3.1 Consulta 6 (duas versões)

# %% [markdown]
# ### 6.3.2 Consulta 7 (duas versões)

# %% [markdown]
# ### 6.3.3 Consulta 8 (duas versões)

# %% [markdown]
# ### 6.4 Duas consultas envolvendo agregação sobre junção de duas ou mais relações

# %% [markdown]
# ### 6.4.1 Consulta 9 (duas versões)

# %% [markdown]
# ### 6.4.2 Consulta 10 (duas versões)

# %% [markdown]
# ### 7. Autoavaliação dos membros
